# %% [markdown]
# FINANCIAL FAQ

# %%
from google.colab import files
files.upload()

# %%
# !ls
# Out:
# sample_data

# %%
import pandas as pd
df = pd.read_csv('Financial-QA-10k.csv')
df.head()
# Out:
#                                             question  \
# 0  What area did NVIDIA initially focus on before...
# 1  What are some of the recent applications of GP...
# 2  What significant invention did NVIDIA create i...
# 3  How does NVIDIA's platform strategy contribute...
# 4  What does NVIDIA's CUDA programming model enable?
#
#                                               answer  \
# 0           NVIDIA initially focused on PC graphics.
# 1  Recent applications of GPU-powered deep learni...
# 2                   NVIDIA invented the GPU in 1999.
# 3  NVIDIA's platform strategy brings together har...
# 4  NVIDIA's CUDA programming model opened the par...
#
#                                              context ticker    filing
# 0  Since our original focus on PC graphics, we ha...   NVDA  2023_10K
# 1  Some of the most recent applications of GPU-po...   NVDA  2023_10K
# 2  Our invention of the GPU in 1999 defined moder...   NVDA  2023_10K
# 3  NVIDIA has a platform strategy, bringing toget...   NVDA  2023_10K
# 4  With our introduction of the CUDA programming ...   NVDA  2023_10K

# %%
df.isnull().sum()
# Out:
# question    2
# answer      2
# context     1
# ticker      0
# filing      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  6998 non-null   object
#  1   answer    6998 non-null   object
#  2   context   6999 non-null   object
#  3   ticker    7000 non-null   object
#  4   filing    7000 non-null   object
# dtypes: object(5)
# memory usage: 273.6+ KB

# %%
df = df.dropna(subset=['question', 'answer'])
df = df.drop_duplicates()

# %%
df[['question','answer']].sample(5)
# Out:
#                                                question  \
# 5037  By how much did Ford Pro's revenue increase fr...
# 1661  Where can one find the consolidated financial ...
# 2418  Where can detailed information about the commi...
# 5083  Where do the Financial Statements and Suppleme...
# 3299       When did AT&T acquire BellSouth Corporation?
#
#                                                  answer
# 5037                                      $6.29 billion
# 1661  The consolidated financial statements can be f...
# 2418         Under Note 13, included in Part II, Item 8
# 5083  The Financial Statements and Supplementary Dat...
# 3299       AT&T acquired BellSouth Corporation in 2006.

# %%
df['ticker'].value_counts()
# Out:
# ticker
# JNJ      199
# AAPL     100
# TSLA     100
# LULU     100
# NVDA     100
#         ...
# HD        99
# CB        99
# GOOGL     98
# GRMN      98
# IBM       98
# Name: count, Length: 69, dtype: int64

# %%
df['filing'].value_counts()
# Out:
# filing
# 2023_10K    6990
# Name: count, dtype: int64

# %%
df.drop(columns=['filing'], inplace=True)

# %%
for col in ['question', 'answer', 'context']:
    df[col] = df[col].str.strip()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                             question  \
# 0  What area did NVIDIA initially focus on before...
# 1  What are some of the recent applications of GP...
# 2  What significant invention did NVIDIA create i...
# 3  How does NVIDIA's platform strategy contribute...
# 4  What does NVIDIA's CUDA programming model enable?
#
#                                               answer  \
# 0           NVIDIA initially focused on PC graphics.
# 1  Recent applications of GPU-powered deep learni...
# 2                   NVIDIA invented the GPU in 1999.
# 3  NVIDIA's platform strategy brings together har...
# 4  NVIDIA's CUDA programming model opened the par...
#
#                                              context ticker
# 0  Since our original focus on PC graphics, we ha...   NVDA
# 1  Some of the most recent applications of GPU-po...   NVDA
# 2  Our invention of the GPU in 1999 defined moder...   NVDA
# 3  NVIDIA has a platform strategy, bringing toget...   NVDA
# 4  With our introduction of the CUDA programming ...   NVDA

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
df = pd.read_csv('faq_cleaned.csv')
df.head()
# Out:
#                                             question  \
# 0  What area did NVIDIA initially focus on before...
# 1  What are some of the recent applications of GP...
# 2  What significant invention did NVIDIA create i...
# 3  How does NVIDIA's platform strategy contribute...
# 4  What does NVIDIA's CUDA programming model enable?
#
#                                               answer  \
# 0           NVIDIA initially focused on PC graphics.
# 1  Recent applications of GPU-powered deep learni...
# 2                   NVIDIA invented the GPU in 1999.
# 3  NVIDIA's platform strategy brings together har...
# 4  NVIDIA's CUDA programming model opened the par...
#
#                                              context ticker
# 0  Since our original focus on PC graphics, we ha...   NVDA
# 1  Some of the most recent applications of GPU-po...   NVDA
# 2  Our invention of the GPU in 1999 defined moder...   NVDA
# 3  NVIDIA has a platform strategy, bringing toget...   NVDA
# 4  With our introduction of the CUDA programming ...   NVDA

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
question_embeddings = model.encode(df['question'].tolist(),show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/219 [00:00<?, ?it/s]

# %%
import numpy as np
np.save('question_embeddings.npy', question_embeddings)

# %%
#testing
user_question = "did Nvidia invent anything in 1999?"
user_question = user_question.strip()
user_question_embedding = model.encode([user_question])[0]

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

similarities = np.dot(question_embeddings, user_question_embedding) / (np.linalg.norm(question_embeddings, axis=1) * np.linalg.norm(user_question_embedding))

top_index = np.argmax(similarities)
top_faq = df.iloc[top_index]
print("best match:",top_faq['question'])
print("answer:",top_faq['answer'])
print("score:",similarities[top_index])
# Out:
# best match: What significant invention did NVIDIA create in 1999?
# answer: NVIDIA invented the GPU in 1999.
# score: 0.93411064
